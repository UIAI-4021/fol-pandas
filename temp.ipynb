# %%
import pandas as pd
import tkinter
import TkinterMapView
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
#       2 import tkinter
# ----> 3 import TkinterMapView
#
# ModuleNotFoundError: No module named 'TkinterMapView'

# %%
dest_df = pd.read_csv('./Destinations.csv')
dest_df
# Out:
#      Destinations      country           region    Climate  Budget   Activity  \
# 0           Tokyo        Japan        East Asia  Temperate    High   Cultural
# 1          Ottawa       Canada    North America       Cold  Medium  Adventure
# 2     Mexico City       Mexico    North America  Temperate     Low   Cultural
# 3            Rome        Italy  Southern Europe  Temperate    High   Cultural
# 4        Brasilia       Brazil    South America   Tropical     Low  Adventure
# ..            ...          ...              ...        ...     ...        ...
# 97          Luxor        Egypt     North Africa     Desert     Low   Cultural
# 98          Aswan        Egypt     North Africa     Desert     Low   Cultural
# 99   Christchurch  New Zealand          Oceania  Temperate  Medium  Adventure
# 100    Queenstown  New Zealand          Oceania  Temperate    High  Adventure
# 101       Rotorua  New Zealand          Oceania  Temperate  Medium   Cultural
#
# ...

# %%
# Create a set of unique features
features = set()
for _, row in dest_df.iterrows():
    for col in row.index:
        if col not in ['Destinations', 'country', 'region']:
            features.add(col)

# Create a dictionary to map features to their names
feature_dict = {feature: col.title() for feature in features}

# Print the features
features
# Out:
# {'Accommodation',
#  'Activity',
#  'Budget',
#  'Climate',
#  'Cuisine',
#  'Demographics',
#  'Duration',
#  'History',
#  'Language',
#  'Natural Wonder'}

# %%
s = set()
s.update(dest_df['Budget'])
s
dest_df.shape
# Out:
# (102, 13)

# %%
my_dict = {
    'key1': [1, 2, 3],
    'key2': [4, 5, 6],
    'key3': [1, 2, 3],
    'key4': [7, 8, 9],
}
for f in my_dict:
    print(f)
# Out:
# key1
# key2
# key3
# key4
